# %% [markdown]
# # NearestNeighbors classifier on MNist data set - Multi machine execution w. DASK

# %% [markdown]
# ## Task 1 - Load the Mnist data set

# %%
from keras.datasets import mnist

# split data into training and testing 60000/10000
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(len(x_train))
print(len(x_test))
print(x_train.shape)
print(x_test.shape)
print(y_train[0:10])
# Out:
# 60000
# 10000
# (60000, 28, 28)
# (10000, 28, 28)
# [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# ## Task 2 - Pre-proccessing of dataset

# %%
from dask.distributed import Scheduler, Worker, Client
client = Client('10.42.0.190:8786')
# Out:
# /opt/conda/envs/rapids/lib/python3.7/site-packages/distributed/client.py:1123: VersionMismatchWarning: Mismatched versions found
#
# +---------+----------------+----------------+----------------+
# | Package | client         | scheduler      | workers        |
# +---------+----------------+----------------+----------------+
# | numpy   | 1.19.5         | 1.21.2         | 1.21.2         |
# | python  | 3.7.10.final.0 | 3.8.12.final.0 | 3.8.12.final.0 |
# +---------+----------------+----------------+----------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
client
# Out:
# <Client: 'tcp://10.42.0.190:8786' processes=10 threads=10, memory=190.88 GiB>

# %%
from cuml.dask.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(client)
# Out:
# /opt/conda/envs/rapids/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass client=<Client: 'tcp://10.42.0.190:8786' processes=10 threads=10, memory=190.88 GiB> as keyword args. From version 21.06, passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
